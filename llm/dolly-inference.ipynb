# %%
import torch
from instruct_pipeline import InstructionTextGenerationPipeline
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
MODEL_PATH = "/NS/twitter-9/work/vnanda/invariances_in_reps/llm/checkpoints/dolly-v2-12b"

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH, 
                                          padding_side="left")
model = AutoModelForCausalLM.from_pretrained(MODEL_PATH, 
                                             device_map="auto", 
                                             torch_dtype=torch.bfloat16)

generate_text = InstructionTextGenerationPipeline(model=model, tokenizer=tokenizer)

# %%
res = generate_text("Explain the difference between nuclear fusion and fission.")

# %%
print (res[0]['generated_text'])
# Out:
# Nuclear fusion occurs when two smaller nuclei join together to form one larger nucleus. This process releases energy. Nuclear fission, on the other hand, occurs when one larger nucleus is broken up into two smaller fragments. This process releases a lot of energy but it's harder to contain.

# %%
generate_text.model
# Out:
# GPTNeoXForCausalLM(
#   (gpt_neox): GPTNeoXModel(
#     (embed_in): Embedding(50280, 5120)
#     (layers): ModuleList(
#       (0): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (1): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (2): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (3): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (4): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (5): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (6): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (7): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (8): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (9): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (10): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (11): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (12): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (13): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (14): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (15): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (16): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (17): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (18): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (19): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (20): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (21): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (22): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (23): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (24): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (25): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (26): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (27): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (28): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (29): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (30): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (31): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (32): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (33): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (34): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#       (35): GPTNeoXLayer(
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): RotaryEmbedding()
#           (query_key_value): Linear(in_features=5120, out_features=15360, bias=True)
#           (dense): Linear(in_features=5120, out_features=5120, bias=True)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=5120, out_features=20480, bias=True)
#           (dense_4h_to_h): Linear(in_features=20480, out_features=5120, bias=True)
#           (act): GELUActivation()
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   )
#   (embed_out): Linear(in_features=5120, out_features=50280, bias=False)
# )

# %%
res = generate_text(
    "If you had to choose, would you rather have [a]A smaller government providing fewer services.[b]A bigger government providing more services")

# %%
print (res[0]['generated_text'])
# Out:
# A bigger government providing more services

# %%
res = generate_text("Which of the following statement come closest to your view?[a]America's openness to people from all over the world is essential to who we are as a nation.[b]If America is too open to people from all over the world, we risk losing our identity as a nation")
res[0]['generated_text']
# Out:
# "America's openness to people from all over the world is essential to who we are as a nation. If America is too closed to people from all over the world, we risk losing our identity as a nation."
