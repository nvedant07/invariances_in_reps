# %%
import glob, os, shutil, itertools

# %%
datasets = ['cifar10', 'cifar100', 'flowers', 'oxford-iiit-pets']
appends = ['nonrob', 'robustl2eps3']

for ds, append in itertools.product(datasets, appends):
    trained_models = glob.glob(
        f'./checkpoints/resnet50-base-imagenet-ft-{ds}/*-{append}/*-layer*-topk=1.ckpt')
    layers_to_fractions_to_seeds = {}
    for m in trained_models:
        layer = m.split('-layer')[1].split('-')[0]
        frac = float(m.split('frac-')[1].split('-')[0])
        seed = int(m.split('-seed-')[1].split('-')[0])
        epoch = m.split('/')[-1].split('-layer')[0]
        if layer not in layers_to_fractions_to_seeds:
            layers_to_fractions_to_seeds[layer] = {frac: set([f'{epoch}-{seed}'])}
        else:
            if frac in layers_to_fractions_to_seeds[layer]:
                layers_to_fractions_to_seeds[layer][frac].add(f'{epoch}-{seed}')
            else:
                layers_to_fractions_to_seeds[layer][frac] = set([f'{epoch}-{seed}'])
    print (f'For dataset {ds} - {append}')
    for l in sorted(layers_to_fractions_to_seeds.keys()):
        print (f'Layer {l}:')
        for f in sorted(layers_to_fractions_to_seeds[l].keys()):
            print (f'Fraction: {f}, seeds done: {" ".join(map(str, list(layers_to_fractions_to_seeds[l][f])))}')
    print ()

# %% [markdown]
# ### Full Feature Progress

# %%
datasets = ['cifar10', 'cifar100', 'flowers', 'oxford-iiit-pets']
appends = ['nonrob', 'robustl2eps3']

for ds, append in itertools.product(datasets, appends):
    trained_models = glob.glob(
        f'./checkpoints/*-base-imagenet-ft-{ds}/*-{append}/*-full-feature-topk=1.ckpt')
    model_to_fraction_to_seeds = {}
    for m in trained_models:
        model = m.split('checkpoints/')[1].split('-')[0]
        frac = float(m.split('frac-')[1].split('-')[0])
        seed = int(m.split('-seed-')[1].split('-')[0])
        epoch = m.split('/')[-1].split('-layer')[0]
        if model not in model_to_fraction_to_seeds:
            model_to_fraction_to_seeds[model] = {frac: set([f'{epoch}-{seed}'])}
        else:
            if frac in model_to_fraction_to_seeds[model]:
                model_to_fraction_to_seeds[model][frac].add(f'{epoch}-{seed}')
            else:
                model_to_fraction_to_seeds[model][frac] = set([f'{epoch}-{seed}'])
    print (f'For dataset {ds} - {append}')
    for l in sorted(model_to_fraction_to_seeds.keys()):
        print (f'Model {l}:')
        for f in sorted(model_to_fraction_to_seeds[l].keys()):
            sorted_seeds = sorted(list(model_to_fraction_to_seeds[l][f]), key=lambda x: int(x.split('-')[-1]))
            print (f'Fraction: {f}, seeds done: '
                   f'{" ".join(map(str, sorted_seeds))}')
    print ()
# Out:
# For dataset cifar10 - nonrob
# Model resnet50:
# Fraction: 0.0, seeds done: epoch=43-full-feature-topk=1.ckpt-1 epoch=32-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=41-full-feature-topk=1.ckpt-4 epoch=24-full-feature-topk=1.ckpt-5
# Fraction: 3.62e-06, seeds done: epoch=39-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=43-full-feature-topk=1.ckpt-5
# Fraction: 1e-05, seeds done: epoch=35-full-feature-topk=1.ckpt-1 epoch=30-full-feature-topk=1.ckpt-2 epoch=21-full-feature-topk=1.ckpt-3 epoch=40-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 1.847e-05, seeds done: epoch=27-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=29-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=22-full-feature-topk=1.ckpt-5
# Fraction: 3.695e-05, seeds done: epoch=12-full-feature-topk=1.ckpt-1 epoch=23-full-feature-topk=1.ckpt-2 epoch=32-full-feature-topk=1.ckpt-3 epoch=31-full-feature-topk=1.ckpt-4 epoch=43-full-feature-topk=1.ckpt-5
# Fraction: 7.408e-05, seeds done: epoch=12-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=29-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.0001, seeds done: epoch=29-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=28-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.0001112, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=28-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.00018546, seeds done: epoch=42-full-feature-topk=1.ckpt-1 epoch=37-full-feature-topk=1.ckpt-2 epoch=19-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.00029666, seeds done: epoch=36-full-feature-topk=1.ckpt-1 epoch=46-full-feature-topk=1.ckpt-2 epoch=45-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.00033379, seeds done: epoch=19-full-feature-topk=1.ckpt-1 epoch=46-full-feature-topk=1.ckpt-2 epoch=45-full-feature-topk=1.ckpt-3 epoch=47-full-feature-topk=1.ckpt-4 epoch=28-full-feature-topk=1.ckpt-5
# Fraction: 0.00037092, seeds done: epoch=36-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=45-full-feature-topk=1.ckpt-3 epoch=45-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.0005, seeds done: epoch=38-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=31-full-feature-topk=1.ckpt-5
# Fraction: 0.005, seeds done: epoch=46-full-feature-topk=1.ckpt-1 epoch=44-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=43-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.05, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=47-full-feature-topk=1.ckpt-3 epoch=35-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.1, seeds done: epoch=47-full-feature-topk=1.ckpt-1 epoch=48-full-feature-topk=1.ckpt-2 epoch=49-full-feature-topk=1.ckpt-3 epoch=35-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.2, seeds done: epoch=47-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=49-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
#
# For dataset cifar10 - robustl2eps3
# Model resnet50:
# Fraction: 0.0, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=36-full-feature-topk=1.ckpt-2 epoch=38-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 3.62e-06, seeds done: epoch=38-full-feature-topk=1.ckpt-1 epoch=39-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=45-full-feature-topk=1.ckpt-4 epoch=22-full-feature-topk=1.ckpt-5
# Fraction: 1e-05, seeds done: epoch=24-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=49-full-feature-topk=1.ckpt-5
# Fraction: 1.847e-05, seeds done: epoch=30-full-feature-topk=1.ckpt-1 epoch=39-full-feature-topk=1.ckpt-2 epoch=42-full-feature-topk=1.ckpt-3 epoch=24-full-feature-topk=1.ckpt-4 epoch=26-full-feature-topk=1.ckpt-5
# Fraction: 3.695e-05, seeds done: epoch=19-full-feature-topk=1.ckpt-1 epoch=30-full-feature-topk=1.ckpt-2 epoch=36-full-feature-topk=1.ckpt-3 epoch=45-full-feature-topk=1.ckpt-4 epoch=48-full-feature-topk=1.ckpt-5
# Fraction: 7.408e-05, seeds done: epoch=24-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=36-full-feature-topk=1.ckpt-3 epoch=45-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.0001, seeds done: epoch=34-full-feature-topk=1.ckpt-1 epoch=38-full-feature-topk=1.ckpt-2 epoch=18-full-feature-topk=1.ckpt-3 epoch=45-full-feature-topk=1.ckpt-4 epoch=40-full-feature-topk=1.ckpt-5
# Fraction: 0.0001112, seeds done: epoch=34-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=39-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.00018546, seeds done: epoch=39-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=39-full-feature-topk=1.ckpt-3 epoch=29-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.00029666, seeds done: epoch=21-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.00033379, seeds done: epoch=19-full-feature-topk=1.ckpt-1 epoch=28-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.00037092, seeds done: epoch=31-full-feature-topk=1.ckpt-1 epoch=49-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=29-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.0005, seeds done: epoch=19-full-feature-topk=1.ckpt-1 epoch=20-full-feature-topk=1.ckpt-2 epoch=34-full-feature-topk=1.ckpt-3 epoch=29-full-feature-topk=1.ckpt-4 epoch=22-full-feature-topk=1.ckpt-5
# Fraction: 0.005, seeds done: epoch=36-full-feature-topk=1.ckpt-1 epoch=33-full-feature-topk=1.ckpt-2 epoch=37-full-feature-topk=1.ckpt-3 epoch=25-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.05, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=26-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=47-full-feature-topk=1.ckpt-5
# Fraction: 0.1, seeds done: epoch=30-full-feature-topk=1.ckpt-1 epoch=38-full-feature-topk=1.ckpt-2 epoch=49-full-feature-topk=1.ckpt-3 epoch=40-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.2, seeds done: epoch=30-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=49-full-feature-topk=1.ckpt-3 epoch=40-full-feature-topk=1.ckpt-4 epoch=47-full-feature-topk=1.ckpt-5
#
# For dataset cifar100 - nonrob
# Model resnet50:
# Fraction: 0.0, seeds done: epoch=11-full-feature-topk=1.ckpt-1 epoch=18-full-feature-topk=1.ckpt-2 epoch=21-full-feature-topk=1.ckpt-3 epoch=44-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
# Fraction: 3.62e-06, seeds done: epoch=21-full-feature-topk=1.ckpt-1 epoch=36-full-feature-topk=1.ckpt-2 epoch=44-full-feature-topk=1.ckpt-3 epoch=20-full-feature-topk=1.ckpt-4 epoch=46-full-feature-topk=1.ckpt-5
# Fraction: 1e-05, seeds done: epoch=48-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=24-full-feature-topk=1.ckpt-3 epoch=48-full-feature-topk=1.ckpt-4 epoch=24-full-feature-topk=1.ckpt-5
# Fraction: 1.847e-05, seeds done: epoch=38-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=20-full-feature-topk=1.ckpt-3 epoch=43-full-feature-topk=1.ckpt-4 epoch=22-full-feature-topk=1.ckpt-5
# Fraction: 3.695e-05, seeds done: epoch=30-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=48-full-feature-topk=1.ckpt-3 epoch=25-full-feature-topk=1.ckpt-4 epoch=29-full-feature-topk=1.ckpt-5
# Fraction: 7.408e-05, seeds done: epoch=28-full-feature-topk=1.ckpt-1 epoch=48-full-feature-topk=1.ckpt-2 epoch=44-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=29-full-feature-topk=1.ckpt-5
# Fraction: 0.0001, seeds done: epoch=42-full-feature-topk=1.ckpt-1 epoch=48-full-feature-topk=1.ckpt-2 epoch=31-full-feature-topk=1.ckpt-3 epoch=19-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.0001112, seeds done: epoch=42-full-feature-topk=1.ckpt-1 epoch=48-full-feature-topk=1.ckpt-2 epoch=25-full-feature-topk=1.ckpt-3 epoch=29-full-feature-topk=1.ckpt-5
# Fraction: 0.00011124, seeds done: epoch=42-full-feature-topk=1.ckpt-4
# Fraction: 0.00018546, seeds done: epoch=32-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=19-full-feature-topk=1.ckpt-3 epoch=43-full-feature-topk=1.ckpt-5
# Fraction: 0.00018553, seeds done: epoch=42-full-feature-topk=1.ckpt-4
# Fraction: 0.00029666, seeds done: epoch=42-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=43-full-feature-topk=1.ckpt-5
# Fraction: 0.00029677, seeds done: epoch=42-full-feature-topk=1.ckpt-4
# Fraction: 0.00033379, seeds done: epoch=45-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=44-full-feature-topk=1.ckpt-3 epoch=43-full-feature-topk=1.ckpt-5
# Fraction: 0.00033392, seeds done: epoch=42-full-feature-topk=1.ckpt-4
# Fraction: 0.00037092, seeds done: epoch=42-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=44-full-feature-topk=1.ckpt-3 epoch=37-full-feature-topk=1.ckpt-5
# Fraction: 0.00037106, seeds done: epoch=42-full-feature-topk=1.ckpt-4
# Fraction: 0.0005, seeds done: epoch=48-full-feature-topk=1.ckpt-1 epoch=38-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=37-full-feature-topk=1.ckpt-5
# Fraction: 0.005, seeds done: epoch=32-full-feature-topk=1.ckpt-1 epoch=23-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=29-full-feature-topk=1.ckpt-5
# Fraction: 0.05, seeds done: epoch=26-full-feature-topk=1.ckpt-1 epoch=30-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=40-full-feature-topk=1.ckpt-4 epoch=48-full-feature-topk=1.ckpt-5
# Fraction: 0.1, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=30-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=37-full-feature-topk=1.ckpt-4 epoch=48-full-feature-topk=1.ckpt-5
# Fraction: 0.2, seeds done: epoch=30-full-feature-topk=1.ckpt-1 epoch=44-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=40-full-feature-topk=1.ckpt-4 epoch=31-full-feature-topk=1.ckpt-5
#
# For dataset cifar100 - robustl2eps3
# Model resnet50:
# Fraction: 0.0, seeds done: epoch=33-full-feature-topk=1.ckpt-1 epoch=34-full-feature-topk=1.ckpt-2 epoch=31-full-feature-topk=1.ckpt-3 epoch=17-full-feature-topk=1.ckpt-4 epoch=18-full-feature-topk=1.ckpt-5
# Fraction: 3.62e-06, seeds done: epoch=45-full-feature-topk=1.ckpt-1 epoch=34-full-feature-topk=1.ckpt-2 epoch=26-full-feature-topk=1.ckpt-3 epoch=28-full-feature-topk=1.ckpt-4 epoch=49-full-feature-topk=1.ckpt-5
# Fraction: 1e-05, seeds done: epoch=30-full-feature-topk=1.ckpt-1 epoch=48-full-feature-topk=1.ckpt-2 epoch=45-full-feature-topk=1.ckpt-3 epoch=18-full-feature-topk=1.ckpt-4 epoch=39-full-feature-topk=1.ckpt-5
# Fraction: 1.847e-05, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=24-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=47-full-feature-topk=1.ckpt-4 epoch=49-full-feature-topk=1.ckpt-5
# Fraction: 3.695e-05, seeds done: epoch=32-full-feature-topk=1.ckpt-1 epoch=38-full-feature-topk=1.ckpt-2 epoch=19-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=28-full-feature-topk=1.ckpt-5
# Fraction: 7.408e-05, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=28-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=47-full-feature-topk=1.ckpt-4 epoch=40-full-feature-topk=1.ckpt-5
# Fraction: 0.0001, seeds done: epoch=23-full-feature-topk=1.ckpt-1 epoch=48-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=47-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.0001112, seeds done: epoch=23-full-feature-topk=1.ckpt-1 epoch=38-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.00018546, seeds done: epoch=41-full-feature-topk=1.ckpt-1 epoch=38-full-feature-topk=1.ckpt-2 epoch=39-full-feature-topk=1.ckpt-3 epoch=32-full-feature-topk=1.ckpt-4 epoch=41-full-feature-topk=1.ckpt-5
# Fraction: 0.00029666, seeds done: epoch=28-full-feature-topk=1.ckpt-1 epoch=38-full-feature-topk=1.ckpt-2 epoch=39-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=32-full-feature-topk=1.ckpt-5
# Fraction: 0.00033379, seeds done: epoch=28-full-feature-topk=1.ckpt-1 epoch=38-full-feature-topk=1.ckpt-2 epoch=39-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=29-full-feature-topk=1.ckpt-5
# Fraction: 0.00037092, seeds done: epoch=28-full-feature-topk=1.ckpt-1 epoch=26-full-feature-topk=1.ckpt-2 epoch=20-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=29-full-feature-topk=1.ckpt-5
# Fraction: 0.0005, seeds done: epoch=28-full-feature-topk=1.ckpt-1 epoch=48-full-feature-topk=1.ckpt-2 epoch=44-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=31-full-feature-topk=1.ckpt-5
# Fraction: 0.005, seeds done: epoch=26-full-feature-topk=1.ckpt-1 epoch=23-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
# Fraction: 0.05, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=44-full-feature-topk=1.ckpt-2 epoch=44-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=38-full-feature-topk=1.ckpt-5
# Fraction: 0.1, seeds done: epoch=46-full-feature-topk=1.ckpt-1 epoch=46-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=38-full-feature-topk=1.ckpt-5
# Fraction: 0.2, seeds done: epoch=33-full-feature-topk=1.ckpt-1 epoch=44-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=33-full-feature-topk=1.ckpt-5
# For dataset flowers - nonrob
# Model resnet50:
# Fraction: 0.0, seeds done: epoch=2-full-feature-topk=1.ckpt-1 epoch=17-full-feature-topk=1.ckpt-2 epoch=35-full-feature-topk=1.ckpt-3 epoch=36-full-feature-topk=1.ckpt-4 epoch=14-full-feature-topk=1.ckpt-5
# Fraction: 3.62e-06, seeds done: epoch=14-full-feature-topk=1.ckpt-1 epoch=33-full-feature-topk=1.ckpt-2 epoch=7-full-feature-topk=1.ckpt-3 epoch=30-full-feature-topk=1.ckpt-4 epoch=12-full-feature-topk=1.ckpt-5
# Fraction: 1e-05, seeds done: epoch=16-full-feature-topk=1.ckpt-1 epoch=12-full-feature-topk=1.ckpt-2 epoch=35-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=24-full-feature-topk=1.ckpt-5
# Fraction: 1.847e-05, seeds done: epoch=17-full-feature-topk=1.ckpt-1 epoch=40-full-feature-topk=1.ckpt-2 epoch=41-full-feature-topk=1.ckpt-3 epoch=43-full-feature-topk=1.ckpt-4 epoch=42-full-feature-topk=1.ckpt-5
# Fraction: 3.695e-05, seeds done: epoch=26-full-feature-topk=1.ckpt-1 epoch=39-full-feature-topk=1.ckpt-2 epoch=19-full-feature-topk=1.ckpt-3 epoch=47-full-feature-topk=1.ckpt-4 epoch=29-full-feature-topk=1.ckpt-5
# Fraction: 7.408e-05, seeds done: epoch=46-full-feature-topk=1.ckpt-1 epoch=40-full-feature-topk=1.ckpt-2 epoch=41-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=20-full-feature-topk=1.ckpt-5
# Fraction: 0.0001, seeds done: epoch=28-full-feature-topk=1.ckpt-1 epoch=47-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=29-full-feature-topk=1.ckpt-4 epoch=37-full-feature-topk=1.ckpt-5
# Fraction: 0.0001112, seeds done: epoch=18-full-feature-topk=1.ckpt-1 epoch=34-full-feature-topk=1.ckpt-2 epoch=43-full-feature-topk=1.ckpt-3 epoch=46-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
# Fraction: 0.00018546, seeds done: epoch=25-full-feature-topk=1.ckpt-1 epoch=24-full-feature-topk=1.ckpt-2 epoch=25-full-feature-topk=1.ckpt-3 epoch=41-full-feature-topk=1.ckpt-4 epoch=28-full-feature-topk=1.ckpt-5
# Fraction: 0.00029666, seeds done: epoch=47-full-feature-topk=1.ckpt-1 epoch=32-full-feature-topk=1.ckpt-2 epoch=49-full-feature-topk=1.ckpt-3 epoch=34-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.00033379, seeds done: epoch=24-full-feature-topk=1.ckpt-1 epoch=34-full-feature-topk=1.ckpt-2 epoch=31-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=24-full-feature-topk=1.ckpt-5
# Fraction: 0.00037092, seeds done: epoch=20-full-feature-topk=1.ckpt-1 epoch=31-full-feature-topk=1.ckpt-2 epoch=38-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=46-full-feature-topk=1.ckpt-5
# Fraction: 0.0005, seeds done: epoch=42-full-feature-topk=1.ckpt-1 epoch=47-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=39-full-feature-topk=1.ckpt-4 epoch=36-full-feature-topk=1.ckpt-5
# Fraction: 0.005, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=31-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=41-full-feature-topk=1.ckpt-4 epoch=22-full-feature-topk=1.ckpt-5
# Fraction: 0.05, seeds done: epoch=26-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=38-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
# Fraction: 0.1, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
# Fraction: 0.2, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=33-full-feature-topk=1.ckpt-2 epoch=38-full-feature-topk=1.ckpt-3 epoch=38-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
#
# For dataset flowers - robustl2eps3
# Model resnet50:
# Fraction: 0.0, seeds done: epoch=33-full-feature-topk=1.ckpt-1 epoch=24-full-feature-topk=1.ckpt-2 epoch=33-full-feature-topk=1.ckpt-3 epoch=3-full-feature-topk=1.ckpt-4 epoch=3-full-feature-topk=1.ckpt-5
# Fraction: 3.62e-06, seeds done: epoch=31-full-feature-topk=1.ckpt-1 epoch=5-full-feature-topk=1.ckpt-2 epoch=39-full-feature-topk=1.ckpt-3 epoch=23-full-feature-topk=1.ckpt-4 epoch=22-full-feature-topk=1.ckpt-5
# Fraction: 1e-05, seeds done: epoch=4-full-feature-topk=1.ckpt-1 epoch=3-full-feature-topk=1.ckpt-2 epoch=27-full-feature-topk=1.ckpt-3 epoch=28-full-feature-topk=1.ckpt-4 epoch=37-full-feature-topk=1.ckpt-5
# Fraction: 1.847e-05, seeds done: epoch=35-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=21-full-feature-topk=1.ckpt-3 epoch=14-full-feature-topk=1.ckpt-4 epoch=26-full-feature-topk=1.ckpt-5
# Fraction: 3.695e-05, seeds done: epoch=9-full-feature-topk=1.ckpt-1 epoch=35-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=41-full-feature-topk=1.ckpt-4 epoch=44-full-feature-topk=1.ckpt-5
# Fraction: 7.408e-05, seeds done: epoch=25-full-feature-topk=1.ckpt-1 epoch=15-full-feature-topk=1.ckpt-2 epoch=14-full-feature-topk=1.ckpt-3 epoch=23-full-feature-topk=1.ckpt-4 epoch=10-full-feature-topk=1.ckpt-5
# Fraction: 0.0001, seeds done: epoch=49-full-feature-topk=1.ckpt-1 epoch=44-full-feature-topk=1.ckpt-2 epoch=24-full-feature-topk=1.ckpt-3 epoch=48-full-feature-topk=1.ckpt-4 epoch=44-full-feature-topk=1.ckpt-5
# Fraction: 0.0001112, seeds done: epoch=38-full-feature-topk=1.ckpt-1 epoch=36-full-feature-topk=1.ckpt-2 epoch=22-full-feature-topk=1.ckpt-3 epoch=21-full-feature-topk=1.ckpt-4 epoch=45-full-feature-topk=1.ckpt-5
# Fraction: 0.00018546, seeds done: epoch=47-full-feature-topk=1.ckpt-1 epoch=34-full-feature-topk=1.ckpt-2 epoch=37-full-feature-topk=1.ckpt-3 epoch=46-full-feature-topk=1.ckpt-4 epoch=18-full-feature-topk=1.ckpt-5
# Fraction: 0.00029666, seeds done: epoch=26-full-feature-topk=1.ckpt-1 epoch=46-full-feature-topk=1.ckpt-2 epoch=31-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=25-full-feature-topk=1.ckpt-5
# Fraction: 0.00033379, seeds done: epoch=44-full-feature-topk=1.ckpt-1 epoch=43-full-feature-topk=1.ckpt-2 epoch=41-full-feature-topk=1.ckpt-3 epoch=30-full-feature-topk=1.ckpt-4 epoch=34-full-feature-topk=1.ckpt-5
# Fraction: 0.00037092, seeds done: epoch=23-full-feature-topk=1.ckpt-1 epoch=37-full-feature-topk=1.ckpt-2 epoch=34-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=48-full-feature-topk=1.ckpt-5
# Fraction: 0.0005, seeds done: epoch=23-full-feature-topk=1.ckpt-1 epoch=37-full-feature-topk=1.ckpt-2 epoch=19-full-feature-topk=1.ckpt-3 epoch=22-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.005, seeds done: epoch=21-full-feature-topk=1.ckpt-1 epoch=29-full-feature-topk=1.ckpt-2 epoch=44-full-feature-topk=1.ckpt-3 epoch=49-full-feature-topk=1.ckpt-4 epoch=27-full-feature-topk=1.ckpt-5
# Fraction: 0.05, seeds done: epoch=22-full-feature-topk=1.ckpt-1 epoch=32-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=42-full-feature-topk=1.ckpt-4 epoch=36-full-feature-topk=1.ckpt-5
# Fraction: 0.1, seeds done: epoch=23-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=33-full-feature-topk=1.ckpt-5
# Fraction: 0.2, seeds done: epoch=32-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=37-full-feature-topk=1.ckpt-3 epoch=32-full-feature-topk=1.ckpt-4 epoch=33-full-feature-topk=1.ckpt-5
#
# For dataset oxford-iiit-pets - nonrob
# Model resnet50:
# Fraction: 0.0, seeds done: epoch=8-full-feature-topk=1.ckpt-1 epoch=4-full-feature-topk=1.ckpt-2 epoch=10-full-feature-topk=1.ckpt-3 epoch=19-full-feature-topk=1.ckpt-4 epoch=37-full-feature-topk=1.ckpt-5
# Fraction: 3.62e-06, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=8-full-feature-topk=1.ckpt-2 epoch=29-full-feature-topk=1.ckpt-3 epoch=22-full-feature-topk=1.ckpt-4 epoch=40-full-feature-topk=1.ckpt-5
# Fraction: 1e-05, seeds done: epoch=39-full-feature-topk=1.ckpt-1 epoch=22-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=14-full-feature-topk=1.ckpt-4 epoch=41-full-feature-topk=1.ckpt-5
# Fraction: 1.847e-05, seeds done: epoch=24-full-feature-topk=1.ckpt-1 epoch=37-full-feature-topk=1.ckpt-2 epoch=36-full-feature-topk=1.ckpt-3 epoch=45-full-feature-topk=1.ckpt-4 epoch=31-full-feature-topk=1.ckpt-5
# Fraction: 3.695e-05, seeds done: epoch=27-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=48-full-feature-topk=1.ckpt-3 epoch=45-full-feature-topk=1.ckpt-4 epoch=23-full-feature-topk=1.ckpt-5
# Fraction: 7.408e-05, seeds done: epoch=35-full-feature-topk=1.ckpt-1 epoch=30-full-feature-topk=1.ckpt-2 epoch=25-full-feature-topk=1.ckpt-3 epoch=46-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
# Fraction: 0.0001, seeds done: epoch=22-full-feature-topk=1.ckpt-1 epoch=32-full-feature-topk=1.ckpt-2 epoch=35-full-feature-topk=1.ckpt-3 epoch=47-full-feature-topk=1.ckpt-4 epoch=20-full-feature-topk=1.ckpt-5
# Fraction: 0.0001112, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=32-full-feature-topk=1.ckpt-2 epoch=35-full-feature-topk=1.ckpt-3 epoch=47-full-feature-topk=1.ckpt-4 epoch=42-full-feature-topk=1.ckpt-5
# Fraction: 0.00018546, seeds done: epoch=34-full-feature-topk=1.ckpt-1 epoch=36-full-feature-topk=1.ckpt-2 epoch=36-full-feature-topk=1.ckpt-3 epoch=44-full-feature-topk=1.ckpt-4 epoch=43-full-feature-topk=1.ckpt-5
# Fraction: 0.00029666, seeds done: epoch=39-full-feature-topk=1.ckpt-1 epoch=40-full-feature-topk=1.ckpt-2 epoch=32-full-feature-topk=1.ckpt-3 epoch=47-full-feature-topk=1.ckpt-4 epoch=34-full-feature-topk=1.ckpt-5
# Fraction: 0.00033379, seeds done: epoch=28-full-feature-topk=1.ckpt-1 epoch=19-full-feature-topk=1.ckpt-2 epoch=43-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
# Fraction: 0.00037092, seeds done: epoch=34-full-feature-topk=1.ckpt-1 epoch=32-full-feature-topk=1.ckpt-2 epoch=36-full-feature-topk=1.ckpt-3 epoch=31-full-feature-topk=1.ckpt-4 epoch=39-full-feature-topk=1.ckpt-5
# Fraction: 0.0005, seeds done: epoch=39-full-feature-topk=1.ckpt-1 epoch=28-full-feature-topk=1.ckpt-2 epoch=32-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=38-full-feature-topk=1.ckpt-5
# Fraction: 0.005, seeds done: epoch=47-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=46-full-feature-topk=1.ckpt-3 epoch=41-full-feature-topk=1.ckpt-4 epoch=31-full-feature-topk=1.ckpt-5
# Fraction: 0.05, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=48-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=49-full-feature-topk=1.ckpt-5
# Fraction: 0.1, seeds done: epoch=28-full-feature-topk=1.ckpt-1 epoch=46-full-feature-topk=1.ckpt-2 epoch=43-full-feature-topk=1.ckpt-3 epoch=37-full-feature-topk=1.ckpt-4 epoch=41-full-feature-topk=1.ckpt-5
# Fraction: 0.2, seeds done: epoch=44-full-feature-topk=1.ckpt-1 epoch=41-full-feature-topk=1.ckpt-2 epoch=43-full-feature-topk=1.ckpt-3 epoch=49-full-feature-topk=1.ckpt-4 epoch=30-full-feature-topk=1.ckpt-5
#
# For dataset oxford-iiit-pets - robustl2eps3
# Model resnet50:
# Fraction: 0.0, seeds done: epoch=48-full-feature-topk=1.ckpt-1 epoch=21-full-feature-topk=1.ckpt-2 epoch=38-full-feature-topk=1.ckpt-3 epoch=37-full-feature-topk=1.ckpt-4 epoch=22-full-feature-topk=1.ckpt-5
# Fraction: 3.62e-06, seeds done: epoch=35-full-feature-topk=1.ckpt-1 epoch=25-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=28-full-feature-topk=1.ckpt-4 epoch=32-full-feature-topk=1.ckpt-5
# Fraction: 1e-05, seeds done: epoch=9-full-feature-topk=1.ckpt-1 epoch=18-full-feature-topk=1.ckpt-2 epoch=49-full-feature-topk=1.ckpt-3 epoch=41-full-feature-topk=1.ckpt-4 epoch=19-full-feature-topk=1.ckpt-5
# Fraction: 1.847e-05, seeds done: epoch=31-full-feature-topk=1.ckpt-1 epoch=43-full-feature-topk=1.ckpt-2 epoch=41-full-feature-topk=1.ckpt-3 epoch=32-full-feature-topk=1.ckpt-4 epoch=33-full-feature-topk=1.ckpt-5
# Fraction: 3.695e-05, seeds done: epoch=39-full-feature-topk=1.ckpt-1 epoch=40-full-feature-topk=1.ckpt-2 epoch=37-full-feature-topk=1.ckpt-3 epoch=13-full-feature-topk=1.ckpt-4 epoch=31-full-feature-topk=1.ckpt-5
# Fraction: 7.408e-05, seeds done: epoch=40-full-feature-topk=1.ckpt-1 epoch=36-full-feature-topk=1.ckpt-2 epoch=43-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=27-full-feature-topk=1.ckpt-5
# Fraction: 0.0001, seeds done: epoch=33-full-feature-topk=1.ckpt-1 epoch=28-full-feature-topk=1.ckpt-2 epoch=40-full-feature-topk=1.ckpt-3 epoch=32-full-feature-topk=1.ckpt-4 epoch=35-full-feature-topk=1.ckpt-5
# Fraction: 0.0001112, seeds done: epoch=41-full-feature-topk=1.ckpt-1 epoch=43-full-feature-topk=1.ckpt-2 epoch=32-full-feature-topk=1.ckpt-3 epoch=38-full-feature-topk=1.ckpt-4 epoch=41-full-feature-topk=1.ckpt-5
# Fraction: 0.00018546, seeds done: epoch=21-full-feature-topk=1.ckpt-1 epoch=26-full-feature-topk=1.ckpt-2 epoch=34-full-feature-topk=1.ckpt-3 epoch=45-full-feature-topk=1.ckpt-4 epoch=18-full-feature-topk=1.ckpt-5
# Fraction: 0.00029666, seeds done: epoch=24-full-feature-topk=1.ckpt-1 epoch=24-full-feature-topk=1.ckpt-2 epoch=29-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=21-full-feature-topk=1.ckpt-5
# Fraction: 0.00033379, seeds done: epoch=25-full-feature-topk=1.ckpt-1 epoch=21-full-feature-topk=1.ckpt-2 epoch=48-full-feature-topk=1.ckpt-3 epoch=19-full-feature-topk=1.ckpt-4 epoch=28-full-feature-topk=1.ckpt-5
# Fraction: 0.00037092, seeds done: epoch=25-full-feature-topk=1.ckpt-1 epoch=32-full-feature-topk=1.ckpt-2 epoch=29-full-feature-topk=1.ckpt-3 epoch=27-full-feature-topk=1.ckpt-4 epoch=21-full-feature-topk=1.ckpt-5
# Fraction: 0.0005, seeds done: epoch=43-full-feature-topk=1.ckpt-1 epoch=37-full-feature-topk=1.ckpt-2 epoch=32-full-feature-topk=1.ckpt-3 epoch=28-full-feature-topk=1.ckpt-4 epoch=41-full-feature-topk=1.ckpt-5
# Fraction: 0.005, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=30-full-feature-topk=1.ckpt-3 epoch=35-full-feature-topk=1.ckpt-4 epoch=18-full-feature-topk=1.ckpt-5
# Fraction: 0.05, seeds done: epoch=36-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=48-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=32-full-feature-topk=1.ckpt-5
# Fraction: 0.1, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=45-full-feature-topk=1.ckpt-2 epoch=48-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=41-full-feature-topk=1.ckpt-5
# Fraction: 0.2, seeds done: epoch=37-full-feature-topk=1.ckpt-1 epoch=37-full-feature-topk=1.ckpt-2 epoch=44-full-feature-topk=1.ckpt-3 epoch=33-full-feature-topk=1.ckpt-4 epoch=41-full-feature-topk=1.ckpt-5
